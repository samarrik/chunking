# %% [markdown]
# ### Chunker experimentation

# %%
from chromadb.utils import embedding_functions

from utils.experiment import Experiment
from chunkers.fixed_token_chunker import FixedTokenChunker

# %%
default_ef = embedding_functions.DefaultEmbeddingFunction()
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-MiniLM-L6-v2"
)


df = pd.read_csv("")

# %%
test = Experiment("wikitexts")
test.evaluate(FixedTokenChunker(chunk_size=400, chunk_overlap=200), default_ef, 3)
# Out:
# {'ids': [['0', '1', '9']], 'embeddings': None, 'documents': [[' = Valkyria Chronicles III = \n Senjō no Valkyria 3 : <unk> Chronicles ( Japanese : 戦場のヴァルキュリア3 , lit . Valkyria of the Battlefield 3 ) , commonly referred to as Valkyria Chronicles III outside Japan , is a tactical role @-@ playing video game developed by Sega and Media.Vision for the PlayStation Portable . Released in January 2011 in Japan , it is the third game in the Valkyria series . Employing the same fusion of tactical and real @-@ time gameplay as its predecessors , the story runs parallel to the first game and follows the " Nameless " , a penal military unit serving the nation of Gallia during the Second Europan War who perform secret black operations and are pitted against the Imperial unit " <unk> Raven " . \n The game began development in 2010 , carrying over a large portion of the work done on Valkyria Chronicles II . While it retained the standard features of the series , it also underwent multiple adjustmen
# ...

# %%
import pandas as pd

df = pd.read_csv("data/queries.csv")

for row in df.iterrows():
    for el in row:
        print(el)
# Out:
# 0
# question      What significant regulatory changes and propos...
# references    [{"content": "My administration announced we\u...
# corpus_id                                    state_of_the_union
# Name: 0, dtype: object
# 1
# question      What reasons did President Biden give for the ...
# references    [{"content": "But unfortunately, politics have...
# corpus_id                                    state_of_the_union
# Name: 1, dtype: object
# 2
# question      How many people are no longer denied health in...
# references    [{"content": "Over 100 million of you can no l...
# corpus_id                                    state_of_the_union
# Name: 2, dtype: object
# 3
# question      Which country is Putin invading, causing chaos...
# references    [{"content": "Overseas, Putin of Russia is on ...
# corpus_id                                    state_of_the_union
# Name: 3, dtype: object
# 4
# question      When did the murder rate experience the sharpe...
# ...
